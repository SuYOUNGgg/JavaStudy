# %%
import numpy as np
from matplotlib import pyplot as plt
x = np.arange(1,11)
y = 2*x +5
# print(x)
# print(y)
plt.plot(x,y,'ob')
plt.show()

# %%
x = np.arange(0,3*np.pi, 0.1)
y = np.sin(x)
#print(x)
plt.title("Sine 그래프")
plt.plot(x,y)
plt.show()
